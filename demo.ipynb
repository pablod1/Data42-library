# %% [markdown]
# ## Demo de prueba con algunas de las funciones de la libreria Data42
#
# #### Para esta prueba utilizaremos el dataset de world happines del año 2015

# %%
import Data42.Cleaning as cl
import Data42.Learning as le
import Data42.Visualization as vi
import pandas as pd
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data/happiness_2015.csv')
df['special_chars'] = '@#_45'
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# ## Cleaning
#
# #### En este modulo podemos encontrar diversas funciones como: Limpieza de missings, la deteccion de outliers y modificar caracters en una determinada columna del dataframe

# %%
cl.missings(df)
# Out:
# No missings found.

# %%
cl.detect_outlier(df,'Freedom')
# Out:
# iqr value :  0.22076249999999997
# lower vale : -0.0028137499999999482 , higher value : 0.8802362499999999
# Outliers (%): 0.0
# This are your outliers
# Series([], Name: Freedom, dtype: float64)
# Your outliers are stored in the variable : outliers, if you want to remove them you can use : df = df.drop(df.YOUR_COLUMN_NAME[outliers], axis = 0)

# %%
cl.modify_characters(df,'special_chars',remove='@',add='adasdqw')
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# ## Visualization
#
#
# #### El modulo de visualización esta compuesto principalmente por graficos y reportes de informacion sobre nuestro dataframe

# %%
vi.data_report_numeric(df)
# Out:
#               Happiness Rank  Happiness Score  Standard Error  \
# n_instancess      158.000000       158.000000      158.000000
# mean               79.493671         5.375734        0.047885
# std                45.754363         1.145010        0.017146
# min                 1.000000         2.839000        0.018480
# max               158.000000         7.587000        0.136930
# q25                40.250000         4.526000        0.037268
# q50                79.500000         5.232500        0.043940
# q75               118.750000         6.243750        0.052300
# missings (%)        0.000000         0.000000        0.000000
# outliers (%)        0.000000         0.000000        6.330000
# skew                0.000414         0.096838        1.964559
#
#               Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# n_instancess                158.000000  158.000000                158.000000
# ...

# %%
vi.pie_random(df['Region'])

# %%
vi.countplot('Region','Region',df)

# %% [markdown]
# ## Machine Learning
#
# #### En este modulo podemos encontrar algoritmos de prediccion y comparativas de correlacion entre nuestras variables

# %%
le.balance_observation(df,'Region')
# Out:
#                           Category  Weight
# 0               Sub-Saharan Africa   25.32
# 1       Central and Eastern Europe   18.35
# 2      Latin America and Caribbean   13.92
# 3                   Western Europe   13.29
# 4  Middle East and Northern Africa   12.66
# 5                Southeastern Asia    5.70
# 6                    Southern Asia    4.43
# 7                     Eastern Asia    3.80
# 8                    North America    1.27
# 9        Australia and New Zealand    1.27

# %%
le.correlation_coeff(df,threshold=0.5)
# Out:
# {'Dystopia Residual',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Freedom',
#  'Health (Life Expectancy)'}
